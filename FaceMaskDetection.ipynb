# %% [markdown]
# **MAJOR PROJECT TO CREATE A CUSTOM YOLO V5 MODEL TO DETECT IF A PERSON IS WEARING A MASK OR NOT .**
# ** By Lakshmi anuja Chereddy**

# %%
from google.colab import drive    # Mounting the Drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5  # Clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 11290, done.
# remote: Total 11290 (delta 0), reused 0 (delta 0), pack-reused 11290
# Receiving objects: 100% (11290/11290), 11.20 MiB | 25.31 MiB/s, done.
# Resolving deltas: 100% (7808/7808), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 5.4 MB/s

# %%
# Traning the model
! python train.py --img 640 --batch 2 --epochs 50 --data custom.yaml --weights yolov5x.pt --nosave --cache
# Out:
# ...
# train: weights=yolov5x.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=2, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-32-gc13d4ce torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# Testing the model with the image having the mask
# !python3 detect.py --source /content/drive/MyDrive/Major_project/test/36.jpg --weights /content/yolov5/runs/train/exp/weights/last.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/last.pt'], source=/content/drive/MyDrive/Major_project/test/36.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-32-gc13d4ce torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86180143 parameters, 0 gradients, 204.0 GFLOPs
# image 1/1 /content/drive/MyDrive/Major_project/test/36.jpg: 640x480 1 mask, Done. (0.184s)
# Speed: 0.6ms pre-process, 184.2ms inference, 2.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
#  **The tested image which is having mask**
#
# ![picture](https://drive.google.com/file/d/1hhVa2M3u7_kpuKuyr2KN4J9-LOhCVIFM/view?usp=sharing)

# %%
# Testing the model with image having no mask
# !python3 detect.py --source /content/drive/MyDrive/Major_project/test/147.png --weights /content/yolov5/runs/train/exp/weights/last.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/last.pt'], source=/content/drive/MyDrive/Major_project/test/147.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-32-gc13d4ce torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86180143 parameters, 0 gradients, 204.0 GFLOPs
# image 1/1 /content/drive/MyDrive/Major_project/test/147.png: 640x512 1 no_mask, Done. (0.204s)
# Speed: 0.7ms pre-process, 203.7ms inference, 4.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %% [markdown]
# **The tested image which is not having mask**
#
# ![picture](https://drive.google.com/file/d/1oJApij7avhM-L3ceH9tN4ZEPsv45VB3G/view?usp=sharing)
